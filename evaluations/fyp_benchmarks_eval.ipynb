# %% [markdown]
# <a href="https://colab.research.google.com/github/osmatrixcode/uom-final-year-project/blob/fyp-benchmarks-eval-notebook/evaluations/fyp_benchmarks_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world
